# %% [markdown]
# To Perform Exploratory Data Analysis on given data set

# %%
import numpy as np
import pandas as pd

# data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# machine learning
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn import preprocessing

# %%
data = pd.read_csv('dataFiles\\Placement.csv')

# %%
data
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# 0     Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1     Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2    Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3     Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4    Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0
# ..         ...    ...      ...            ...    ...         ...       ...
# 210  Comm&Mgmt     No     91.0        Mkt&Fin  74.49      Placed  400000.0
# 211   Sci&Tech     No     74.0        Mkt&Fin  53.62      Placed  275000.0
# 212  Comm&Mgmt    Yes     59.0        Mkt&Fin  69.72      Placed  295000.0
# 213  Comm&Mgmt     No     70.0         Mkt&HR  60.23      Placed  204000.0
# 214  Comm&Mgmt     No     89.0         Mkt&HR  60.22  Not Placed       NaN
#
# [215 rows x 15 columns]

# %%
data.head(9)
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
# 5      6      M  55.00   Others  49.80   Others   Science     67.25
# 6      7      F  46.00   Others  49.20   Others  Commerce     79.00
# 7      8      M  82.00  Central  64.00  Central   Science     66.00
# 8      9      M  73.00  Central  79.00  Central  Commerce     72.00
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No    55.00         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes    86.50        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No    75.00        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No    66.00         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No    96.80        Mkt&Fin  55.50      Placed  425000.0
# 5   Sci&Tech    Yes    55.00        Mkt&Fin  51.58  Not Placed       NaN
# 6  Comm&Mgmt     No    74.28        Mkt&Fin  53.29  Not Placed       NaN
# 7   Sci&Tech    Yes    67.00        Mkt&Fin  62.14      Placed  252000.0
# 8  Comm&Mgmt     No    91.34        Mkt&Fin  61.29      Placed  231000.0

# %%
data.tail(10)
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 205    206      M  61.00   Others   62.0   Others  Commerce      65.0
# 206    207      M  41.00  Central   42.0  Central   Science      60.0
# 207    208      M  83.33  Central   78.0   Others  Commerce      61.0
# 208    209      F  43.00  Central   60.0   Others   Science      65.0
# 209    210      M  62.00  Central   72.0  Central  Commerce      65.0
# 210    211      M  80.60   Others   82.0   Others  Commerce      77.6
# 211    212      M  58.00   Others   60.0   Others   Science      72.0
# 212    213      M  67.00   Others   67.0   Others  Commerce      73.0
# 213    214      F  74.00   Others   66.0   Others  Commerce      58.0
# 214    215      M  62.00  Central   58.0   Others   Science      53.0
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# 205  Comm&Mgmt     No    62.00        Mkt&Fin  56.81      Placed  250000.0
# 206  Comm&Mgmt     No    97.00        Mkt&Fin  53.39  Not Placed       NaN
# 207  Comm&Mgmt    Yes    88.56        Mkt&Fin  71.55      Placed  300000.0
# 208  Comm&Mgmt     No    92.66         Mkt&HR  62.92  Not Placed       NaN
# 209  Comm&Mgmt     No    67.00        Mkt&Fin  56.49      Placed  216000.0
# 210  Comm&Mgmt     No    91.00        Mkt&Fin  74.49      Placed  400000.0
# 211   Sci&Tech     No    74.00        Mkt&Fin  53.62      Placed  275000.0
# 212  Comm&Mgmt    Yes    59.00        Mkt&Fin  69.72      Placed  295000.0
# 213  Comm&Mgmt     No    70.00         Mkt&HR  60.23      Placed  204000.0
# 214  Comm&Mgmt     No    89.00         Mkt&HR  60.22  Not Placed       NaN

# %%
print(data.columns.values)
# Out:
# ['sl_no' 'gender' 'ssc_p' 'ssc_b' 'hsc_p' 'hsc_b' 'hsc_s' 'degree_p'
#  'degree_t' 'workex' 'etest_p' 'specialisation' 'mba_p' 'status' 'salary']

# %%
data.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
print('='*100)
print("Describe data")
print('='*50) 
print(data.describe())
# Out:
# ====================================================================================================
# Describe data
# ==================================================
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
#As it is clear that we don't need sl_no in training model or in EDA. Thus I am dropping sl_n column. Rest of them I will keep as it is. After performing EDA I will drop other if needed.

# %%
data = data.drop(['sl_no'], axis=1)

# %%
#Exploring important features

# %%
data['status'].value_counts()
# Out:
# status
# Placed        148
# Not Placed     67
# Name: count, dtype: int64

# %%
sns.countplot( data=data,x=data['status'])
# Out:
# <Axes: xlabel='status', ylabel='count'>

# %%
data['gender'].value_counts()
# Out:
# gender
# M    139
# F     76
# Name: count, dtype: int64

# %%
df = pd.DataFrame(data.groupby(['gender','status'])['status'].count())
df
# Out:
#                    status
# gender status
# F      Not Placed      28
#        Placed          48
# M      Not Placed      39
#        Placed         100

# %%
sns.countplot(x='gender', hue='status', data=data)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
#Conclusion: Male have high chances of getting placed compared to females.

# %%
#SSC Percentage

# %%
sns.displot(data['ssc_p'])
plt.title('Distribution of SSC Percentage')
plt.xlabel('SSC %')
# Out:
# Text(0.5, 9.444444444444438, 'SSC %')

# %%
sns.catplot(y='ssc_p', x='status', data=data)
plt.xlabel('Employment Status')
plt.ylabel('SSC %')
# Out:
# Text(30.375617283950618, 0.5, 'SSC %')

# %%
data['ssc_b'].value_counts()
# Out:
# ssc_b
# Central    116
# Others      99
# Name: count, dtype: int64

# %%
df = pd.DataFrame(data.groupby(['ssc_b','status'])['status'].count())
df
# Out:
#                     status
# ssc_b   status
# Central Not Placed      38
#         Placed          78
# Others  Not Placed      29
#         Placed          70

# %%
sns.countplot(x='ssc_b', hue='status', data=data)
# Out:
# <Axes: xlabel='ssc_b', ylabel='count'>

# %%
#conclusion: From the above analysis I can say that, SSC board is not important to recruiters when it come to hiring candidates. So I am not going to use this feature while training model.

# %%
#HSC Percentage

# %%
sns.distplot(data['hsc_p'], kde=False)
plt.title('Distribution of HSC Percentage')
plt.xlabel('HSC %')
# Out:
# C:\Users\laxmi\AppData\Local\Temp\ipykernel_980\312340977.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['hsc_p'], kde=False)
# Text(0.5, 0, 'HSC %')

# %%
sns.catplot(y='hsc_p', x='status', data=data)
plt.xlabel('Employment Status')
plt.ylabel('HSC %')
# Out:
# Text(30.71381172839505, 0.5, 'HSC %')

# %%
#Conclusion: HSC percentage are important features. As all placed students have higher percentages.

# %%
#EDA for HSC Board

# %%
data['hsc_b'].value_counts()
# Out:
# hsc_b
# Others     131
# Central     84
# Name: count, dtype: int64

# %%
df = pd.DataFrame(data.groupby(['hsc_b','status'])['status'].count())
df
# Out:
#                     status
# hsc_b   status
# Central Not Placed      27
#         Placed          57
# Others  Not Placed      40
#         Placed          91

# %%
sns.countplot(x='hsc_b', hue='status', data=data)
# Out:
# <Axes: xlabel='hsc_b', ylabel='count'>

# %%
#Conclusion: From the above analysis I can say that, hSC board is not important to recruiters when it come to hiring candidates. So I am not going to use this feature while training model.

# %%
#EDA for HSC Specialisation

# %%
data['hsc_s'].value_counts()
# Out:
# hsc_s
# Commerce    113
# Science      91
# Arts         11
# Name: count, dtype: int64

# %%
df = pd.DataFrame(data.groupby(['hsc_s','status'])['status'].count())
df
# Out:
#                      status
# hsc_s    status
# Arts     Not Placed       5
#          Placed           6
# Commerce Not Placed      34
#          Placed          79
# Science  Not Placed      28
#          Placed          63

# %%
sns.countplot(x='hsc_s', hue='status', data=data)
# Out:
# <Axes: xlabel='hsc_s', ylabel='count'>

# %%
#Degree Percentage

# %%
sns.distplot(data['degree_p'], kde=False)
plt.title('Distribution of Degree Percentage')
plt.xlabel('Degree %')
# Out:
# C:\Users\laxmi\AppData\Local\Temp\ipykernel_980\3235349020.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['degree_p'], kde=False)
# Text(0.5, 0, 'Degree %')

# %%
sns.catplot(y='degree_p', x='status', data=data)
plt.xlabel('Employment Status')
plt.ylabel('Degree %')
# Out:
# Text(30.519367283950622, 0.5, 'Degree %')

# %%
#conclusion: Like SSC and HSC percentages, Degree Percentages are also impotant factor to get placed.

# %%
#Work Experience

# %%
data['workex'].value_counts()
# Out:
# workex
# No     141
# Yes     74
# Name: count, dtype: int64

# %%
df = pd.DataFrame(data.groupby(['workex','status'])['status'].count())
df
# Out:
#                    status
# workex status
# No     Not Placed      57
#        Placed          84
# Yes    Not Placed      10
#        Placed          64

# %%
sns.countplot(x='workex', hue='status', data=data)
# Out:
# <Axes: xlabel='workex', ylabel='count'>

# %%
##Conclusion: It is clear that candidate with work experience have higher chance of getting placed.

# %%
## . Employment Test Percentage"

# %%
sns.distplot(data['etest_p'], kde=False)
plt.title('Distribution of MBA Percentage')
plt.xlabel('Employment Test %')
# Out:
# C:\Users\laxmi\AppData\Local\Temp\ipykernel_980\686553525.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['etest_p'], kde=False)
# Text(0.5, 0, 'Employment Test %')

# %%
sns.catplot(y='etest_p', x='status', data=data)
plt.xlabel('Employment Status')
plt.ylabel('Employment Test %')
# Out:
# Text(30.570061728395068, 0.5, 'Employment Test %')

# %%
## Corelation between Features

# %%
sns.pairplot(data=data[['ssc_p','hsc_p','degree_p', 'etest_p','mba_p','salary', 'status']], hue="status", diag_kind='hist')

# %%
#Feature mapping

# %% [markdown]
# Let's drop all unwanted columns as menstioned in above section.<br>
#
#
# SSC Board <br>
# HSC Board<br>
# HSC Specialisation<br>
# Degree Type<br>
# Salary<br>

# %%
data.drop(['ssc_b','hsc_b', 'hsc_s', 'degree_t', 'salary'], axis=1, inplace=True)

# %% [markdown]
# Let's map categorical feature to numeric one. Categorical features:<br>
#
# Gender : Gender feature have male and female values. I am going to map 0 for male and 1 for female.<br>
# Work Experience : Work Experience feature have Yes and No values. I am going to map 0 for No and 1 for Yes.<br>
# Status : Status feature have Not Placed and Placed values. Again for this features I am mapping 0 for not placed and 1 for placed values.<br>
# Specialisation : Specialisation feature have two values Mkt&HR and Mkt&Fin. I am going to map 0 to Mkt&HR and 1 to Mkt&Fin. <br>

# %%
data["gender"] = data.gender.map({"M":0,"F":1})
data["workex"] = data.workex.map({"No":0, "Yes":1})
data["status"] = data.status.map({"Not Placed":0, "Placed":1})
data["specialisation"] = data.specialisation.map({"Mkt&HR":0, "Mkt&Fin":1})

# %%
data.columns
# Out:
# Index(['gender', 'ssc_p', 'hsc_p', 'degree_p', 'workex', 'etest_p',
#        'specialisation', 'mba_p', 'status'],
#       dtype='object')

# %%
data.head()
# Out:
#    gender  ssc_p  hsc_p  degree_p  workex  etest_p  specialisation  mba_p  \
# 0       0  67.00  91.00     58.00       0     55.0               0  58.80
# 1       0  79.33  78.33     77.48       1     86.5               1  66.28
# 2       0  65.00  68.00     64.00       0     75.0               1  57.80
# 3       0  56.00  52.00     52.00       0     66.0               0  59.43
# 4       0  85.80  73.60     73.30       0     96.8               1  55.50
#
#    status
# 0       1
# 1       1
# 2       1
# 3       0
# 4       1
